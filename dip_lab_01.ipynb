# %% [markdown]
# Lab-1: Color Space Conversion

# %% [markdown]
# Library

# %%
import PIL.Image as image
import matplotlib.pyplot as plt

# %% [markdown]
# 1.	Read an image.

# %%
rgb_img=image.open('rglhs_logo.png')
plt.imshow(rgb_img)
plt.show()

# %% [markdown]
# 2.	Display the image resolution in the format: Resolution = Width × Height pixels.

# %%
width,height=rgb_img.size
print(f'Resolition is: {width}px x {height}px')
# Out:
# Resolition is: 250px x 250px

# %% [markdown]
# 3.	Print the image color mode.

# %%
image_mode=rgb_img.mode
print(image_mode)
# Out:
# RGBA

# %% [markdown]
# 4.	Convert the image into grayscale.

# %%
gray_img=rgb_img.convert('L')

# %% [markdown]
# 5.	Display both the original image and the grayscale image.
# 6.	Label each displayed image with an appropriate title.

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(rgb_img)
plt.title('Original Image')
plt.subplot(1, 2, 2)
plt.imshow(gray_img, cmap='gray')
plt.title('Grayscale Image')
plt.show()

# %% [markdown]
# 7.	Save the grayscale image.

# %%
gray_img.save('rglhs_logo.png')
